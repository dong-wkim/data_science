# %% [markdown]
# ---
# title: DSC 530 Weeks 1 & 2 Coding Assignment
# Due: 2025-12-08 7:00 AM CET
# BRUIN ID: 21399491

# %% [markdown]
# # Chapter 3

# %% [markdown]
# ## Exercise 1

# %%
import pandas as pd
import numpy as np

# import csv file as data frames using pandas and store them as variables
aapl = pd.read_csv("data/aapl.csv")
amzn = pd.read_csv("data/amzn.csv")
goog = pd.read_csv("data/googl.csv")
nflx = pd.read_csv("data/nflx.csv")

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# ## Exercise 4
